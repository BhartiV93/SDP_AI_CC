# %% [markdown]
# # Task 1: Create a CNN based Model for Text Classification

# %% [markdown]
# ## CNNs for Texts

# %% [markdown]
# <a name='2'></a>
#
# # Task 2: Combine CNN with RNN

# %% [markdown]
# ## Convnets and RNNs Model for Text Classification
