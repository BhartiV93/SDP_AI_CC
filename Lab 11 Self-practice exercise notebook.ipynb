# %% [markdown]
# ## EDUNET FOUNDATION - Self-Practice Exercise Notebook

# %% [markdown]
# ### LAB 11 - Implementing Pandas Concepts in Python

# %% [markdown]
# ### Pandas

# %% [markdown]
# **Problem 1:** Write a Pandas program to convert a Panda module Series to Python list and it's type.

# %% [markdown]
# **Problem 2:** Write a Pandas program to compare the elements of the two Pandas Series.
# Sample Series: [2, 4, 6, 8, 10], [1, 3, 5, 7, 10]

# %% [markdown]
# **Problem 3:** Write a Pandas program to convert a dictionary to a Pandas series.
#     Sample Series:
# Original dictionary:
# {'a': 100, 'b': 200, 'c': 300, 'd': 400, 'e': 800}
#
# Converted series:
# a    100
# b    200
# c    300
# d    400
# e    800
# dtype: int64

# %% [markdown]
# **Problem 4:** Write a Pandas program to convert the first column of a DataFrame as a Series.
# Sample Output:
# Original DataFrame
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     5
# 2     3     6     8
# 3     4     9    12
# 4     7     5     1
# 5    11     0    11
#
# 1st column as a Series:
# 0     1
# 1     2
# 2     3
# 3     4
# 4     7
# 5    11
# Name: col1, dtype: int64
# <class 'pandas.core.series.Series'>

# %% [markdown]
# **Problem 5:** Write a Pandas program to add some data to an existing Series.
# Sample Output:
# Original Data Series:
# 0       100
# 1       200
# 2    python
# 3    300.12
# 4       400
# dtype: object
#
# Data Series after adding some data:
# 0       100
# 1       200
# 2    python
# 3    300.12
# 4       400
# 5       500
# 6       php
# dtype: object

# %% [markdown]
# **Problem 6:** Write a Pandas program to detect missing values of a given DataFrame. Display True or False.
# Test Data:
#     ![image.png](attachment:image.png)

# %% [markdown]
# **Problem 7:** Write a Pandas program to keep the rows with at least 2 NaN values in a given DataFrame.
# Test Data:
# ![image.png](attachment:image.png)

# %% [markdown]
# **Problem 8:** Write a Pandas program to split the following dataframe by school code and get mean, min, and max value of age for each school.
# Test Data:
# ![image.png](attachment:image.png)
